# %% [markdown]
# <a href="https://colab.research.google.com/github/RiskiSaraan/Tugas-Python_1101190123_Muhammad-Riski-Saraan/blob/main/Muhammad_Riski_Saraan_1101190123_TT_43_G3_PYTHON_FOR_WIRELESS_COMMUNICATION_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Muhammad Riski Saraan**_**1101190123_TT-43-G3**

# %% [markdown]
# # TUGAS BESAR BAGIAN 4
# # PYTHON FOR WIRELESS COMMUNICATION MODEL

# %% [markdown]
# # **1. Fungsi perhitungan daya terima :**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='Urban' :
        Cm=0
    elif tipe=='Suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='Open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=1800 #MHz
loc1='Urban'
loc2='Suburban'
loc3='Open'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m 
Ptx= 30000 #miliwatt
Gtx= 10 #db
Grx= 2 #db
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
NtL = lambda x : 10*np.log10(x)
LtN = lambda x : 10**(x/10)

# %%
Ptx_convert= NtL(Ptx)

# %%
def Prx(ptx,PL,gain_tr,gain_rv):
    Ptx_convert= NtL(ptx) 
    prx = Ptx_convert - (PL + gain_tr + gain_rv)
    Prx_convert= LtN(prx) 

    return Prx_convert #miliwatt

# %% [markdown]
# **GRAFIK-1(GRAFIK VARIASI LOKASI DENGAN FREKUENSI 1800 MHZ)**

# %%
LpUrban=cos(f,loc1,tower,user,d)
LpSuburban=cos(f,loc2,tower,user,d)
LpOpen=cos(f,loc3,tower,user,d)

# %%
Prx_Urban=Prx(Ptx_convert,LpUrban,Gtx,Grx )
Prx_Suburban=Prx(Ptx_convert,LpSuburban,Gtx,Grx)
Prx_Open=Prx(Ptx_convert,LpOpen,Gtx,Grx)

# %%
d_sort=d[np.argsort(d)]
Urban_sort=Prx_Urban[np.argsort(d)]
Suburban_sort=Prx_Suburban[np.argsort(d)]
Open_sort=Prx_Open[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban_sort,'k-', label='Urban')
plt.plot(d_sort,Suburban_sort,'g-', label='Suburban')
plt.plot(d_sort,Open_sort,'r-', label='Open')
plt.legend()
plt.title('Daya Terima Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Daya Terima (miliWatt)')
plt.show()

# %% [markdown]
# **GRAFIK-2(GRAFIK VARIASI FREKUENSI DENGAN LOKASI URBAN)**

# %%
f1=700 #MHz
f2=900 #MHz
f3=1800 #MHz
loc='Urban'

# %%
LpUrban1=cos(f1,loc,tower,user,d)
LpUrban2=cos(f2,loc,tower,user,d)
LpUrban3=cos(f3,loc,tower,user,d)

# %%
Prx_Urban1=Prx(Ptx_convert,LpUrban1,Gtx,Grx )
Prx_Urban2=Prx(Ptx_convert,LpUrban2,Gtx,Grx)
Prx_Urban3=Prx(Ptx_convert,LpUrban3,Gtx,Grx)

# %%
d_sort=d[np.argsort(d)]
Urban1_sort=Prx_Urban1[np.argsort(d)]
Urban2_sort=Prx_Urban2[np.argsort(d)]
Urban3_sort=Prx_Urban3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,Urban1_sort,'k-', label='700 MHz')
plt.plot(d_sort,Urban2_sort,'g-', label='900 MHz')
plt.plot(d_sort,Urban3_sort,'r-', label='1800 MHz')
plt.legend()
plt.title('Model Urban Daya Terima')
plt.xlabel('Jarak (m)')
plt.ylabel('Daya Terima (miliWatt)')
plt.show()

# %% [markdown]
# # **2. FUNGSI PERHITUNGAN SIGNAL TO NOISE RATIO (SNR):**

# %%
BW= 5000000 #Hz

# %%
def snr(Prx, bw):
  noise=-174 + NtL(bw)
  Noise=LtN(noise)
  SNR=Prx/Noise
  return SNR

# %% [markdown]
# **GRAFIK-1(GRAFIK VARIASI LOKASI DENGAN FREKUENSI 1800 MHZ)**

# %%
SNR_Urban=snr(Prx_Urban,BW )
SNR_Suburban=snr(Prx_Suburban,BW)
SNR_Open=snr(Prx_Open,BW)

# %%
d_sort=d[np.argsort(d)]
snrUrban_sort=SNR_Urban[np.argsort(d)]
snrSuburban_sort=SNR_Suburban[np.argsort(d)]
snrOpen_sort=SNR_Open[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,snrUrban_sort,'b-', label='700 MHz')
plt.plot(d_sort,snrSuburban_sort,'r-', label='900 MHz')
plt.plot(d_sort,snrOpen_sort,'g-', label='1800 MHz')
plt.legend()
plt.title('SNR Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('SNR (dB)')
plt.show()

# %% [markdown]
# **GRAFIK-2(GRAFIK VARIASI FREKUENSI DENGAN LOKASI URBAN)**

# %%
SNR_Urban1=snr(Prx_Urban1,BW)
SNR_Urban2=snr(Prx_Urban2,BW)
SNR_Urban3=snr(Prx_Urban3,BW)

# %%
d_sort=d[np.argsort(d)]
snrUrban1_sort=SNR_Urban1[np.argsort(d)]
snrUrban2_sort=SNR_Urban2[np.argsort(d)]
snrUrban3_sort=SNR_Urban3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,snrUrban1_sort,'b-', label='700 MHz')
plt.plot(d_sort,snrUrban2_sort,'r-', label='900 MHz')
plt.plot(d_sort,snrUrban3_sort,'g-', label='1800 MHz')
plt.legend()
plt.title('Model Urban SNR')
plt.xlabel('Jarak (m)')
plt.ylabel('SNR (dB)')
plt.show()

# %% [markdown]
# # **3. Fungsi Perhitungan Kapasitas Seluler :**

# %%
def C(Snr,Bw):
    capacity= Bw*np.log2(1+Snr)
    return capacity

# %% [markdown]
# **GRAFIK-1(GRAFIK VARIASI LOKASI DENGAN FREKUENSI 1800 MHZ)**

# %%
C_Urban=C(SNR_Urban,BW)
C_Suburban=C(SNR_Suburban,BW)
C_Open=C(SNR_Open,BW)

# %%
d_sort=d[np.argsort(d)]
UrbanC_sort=C_Urban[np.argsort(d)]
SuburbanC_sort=C_Suburban[np.argsort(d)]
OpenC_sort=C_Open[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,UrbanC_sort,'y-', label='700 MHz')
plt.plot(d_sort,SuburbanC_sort,'r-', label='900 MHz')
plt.plot(d_sort,OpenC_sort,'g', label='1800 MHz')
plt.legend()
plt.title('Kapasitas Seluler Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Kapasitas (Bps)')
plt.show()

# %% [markdown]
# **GRAFIK-2(GRAFIK VARIASI FREKUENSI DENGAN LOKASI URBAN)**

# %%
C_Urban1=C(SNR_Urban1,BW)
C_Urban2=C(SNR_Urban2,BW)
C_Urban3=C(SNR_Urban3,BW)

# %%
d_sort=d[np.argsort(d)]
UrbanC1_sort=C_Urban1[np.argsort(d)]
UrbanC2_sort=C_Urban2[np.argsort(d)]
UrbanC3_sort=C_Urban3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,UrbanC1_sort,'y-', label='700 Mhz')
plt.plot(d_sort,UrbanC2_sort,'r-', label='900 Mhz')
plt.plot(d_sort,UrbanC3_sort,'g-', label='1800 Mhz')
plt.legend()
plt.title('Kapasitas Seluler Model Urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Kapasitas (Bps)')
plt.show()
